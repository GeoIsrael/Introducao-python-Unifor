# %%
from IPython.display import Image

# %%
Image('desafio.png')

# %%
def num_fibonacci(t,x=0,y=1):
    z=0
    print(x)
    print(y)
    for i in range(t):
        z=x+y
        print(f"{z} ({x}+{y}={z})")
        x=y
        y=z

# %%
num_fibonacci(10)
# Out:
# 0
# 1
# 1 (0+1=1)
# 2 (1+1=2)
# 3 (1+2=3)
# 5 (2+3=5)
# 8 (3+5=8)
# 13 (5+8=13)
# 21 (8+13=21)
# 34 (13+21=34)
# 55 (21+34=55)
# 89 (34+55=89)
